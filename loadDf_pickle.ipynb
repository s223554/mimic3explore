# %%
import pandas as pd
import re
text = pd.read_pickle('noteText.pkl')
gcs = pd.read_pickle('gcs.pkl')

# %%
import datetime
gcs['newdate'] = gcs['charttime'].apply(lambda x: datetime.date(x.year,x.month,x.day))
text['newdate'] = text['chartdate'].apply(lambda x: datetime.date(x.year,x.month,x.day))

# %%
gcs.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>subject_id</th>
#       <th>charttime</th>
#       <th>itemid</th>
#       <th>valuenum</th>
#       <th>newdate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>2191-03-16 08:00:00</td>
#       <td>198</td>
#       <td>15.0</td>
#       <td>2191-03-16</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6</td>
#       <td>2175-05-31 02:00:00</td>
#       <td>198</td>
#       <td>15.0</td>
#       <td>2175-05-31</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>13</td>
#       <td>2167-01-11 05:00:00</td>
#       <td>198</td>
# ...

# %%
# try to join the two table on newdate and subject_id
gcs_text = pd.merge(gcs,text,how = 'left',on = ['subject_id','newdate'])
gcs_text.to_pickle('gcs_text.pkl')

# %%
import pandas as pd
gcs_text = pd.read_pickle('gcs_text.pkl')
gcs_text.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>subject_id</th>
#       <th>charttime</th>
#       <th>itemid</th>
#       <th>valuenum</th>
#       <th>newdate</th>
#       <th>chartdate</th>
#       <th>description</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>4</td>
#       <td>2191-03-16 08:00:00</td>
#       <td>198</td>
#       <td>15.0</td>
#       <td>2191-03-16</td>
#       <td>2191-03-16</td>
#       <td>CHEST (PORTABLE AP)</td>
#       <td>[**2191-3-16**] 12:57 PM\n CHEST (PORTABLE AP)...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>2191-03-16 08:00:00</td>
# ...

# %%
# filter out notes
# key step: to list
des_list = gcs_text['description'].tolist()
dd = des_list[100:500]
note_index = [True for s in dd if 'note' in s]

# %%
note_index.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-ad0fcc6fee3c> in <module>()
# ----> 1 note_index.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
d_list
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CHEST (PORTABLE AP)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Report</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Report</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Report</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>R RENAL TRANSPLANT U.S. RIGHT</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Report</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Report</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>CHEST (PORTABLE AP)</td>
# ...

# %%
# Out:
# ['CHEST (PORTABLE AP)', 'Report', 'Report', 'Report', 'R RENAL TRANSPLANT U.S. RIGHT']
